-- %%
SELECT
    month__name,
    sum(total_amount_inr) AS revenue
FROM fmcg.gold.vw_fact_orders_enriched
GROUP BY month__name
ORDER BY month__name;
